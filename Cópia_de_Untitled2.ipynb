# %%
import matplotlib.pyplot as plt

# lista para armazenar os livros
biblioteca = []

# função para cadastrar novo livro
def cadastrar_livro():
    titulo = input('titulo:')
    autor = input('autor:')
    ano = input('ano:')
    genero = input('genero:')
    livro = {
        'titulo':titulo,
        'autor': autor,
        'ano':ano,
        'genero': genero
    }
    biblioteca.append(livro)
    print('livro cadastrado com sucesso!')

#função para listar todos os livros
def listar_livros():
    if not biblioteca:
      print('nenhum livro cadastrado.')
import matplotlib.pyplot as plt

# lista para armazenar os livros
biblioteca = []

# função para cadastrar novo livro
def cadastrar_livro():
    titulo = input('titulo:')
    autor = input('autor:')
    ano = input('ano:')
    genero = input('genero:')
    livro = {
        'titulo':titulo,
        'autor': autor,
        'ano':ano,
        'genero': genero
    }
    biblioteca.append(livro)
    print('livro cadastrado com sucesso!')

#função para listar todos os livros
def listar_livros():
    if not biblioteca:
      print('nenhum livro cadastrado.')
import matplotlib.pyplot as plt

# lista para armazenar os livros
biblioteca = []

# função para cadastrar novo livro
def cadastrar_livro():
    titulo = input('titulo:')
    autor = input('autor:')
    ano = input('ano:')
    genero = input('genero:')
    livro = {
        'titulo':titulo,
        'autor': autor,
        'ano':ano,
        'genero': genero
    }
    biblioteca.append(livro)
    print('livro cadastrado com sucesso!')

#função para listar todos os livros
def listar_livros():
    if not biblioteca:
      print('nenhum livro cadastrado.')
      return
    for i, livro in enumerate(biblioteca, start=1):
      print(f"{i}. {livro['titulo']} - {livro['autor']} ({livro['ano']}) | genero: {livro['genero']}")

#função para buscar um livro pelo titulo
def buscar_livro():
    termo = input('digite o titulo do livro:').lower()
    encontrados = [livro for livro in biblioteca if termo in livro['titulo'].lower()]
    if encontrados:
       print('livros encontrados:')
       for livro in encontrados:
          print(f"{livro['titulo']} - {livro['autor']} ({livro['ano']}) | genero: {livro['genero']}")
    else:
      print('Nenhum livro encontrado com esse titulo.')

# função para gerar grafico por genero
def gerar_grafico():
  if not biblioteca:
     print('nenhum livro para gerar grafico.')
     return
  generos = {}
  for livro in biblioteca:
      genero = livro['genero']
      generos[genero] = generos.get(genero, 0) + 1

  plt.bar(generos.keys(), generos.values(), color='skyblue')
  plt.xlabel('genero')
  plt.ylabel('quantidade de livros')
  plt.title('livros por genero')
  plt.xticks(rotation=45)
  plt.tight_layout()
  plt.show()

# menu principal
def menu():
    while True:
      print('\n--- Biblioteca ---')
      print('1. cadastrar livro')
      print('2. listar livros')
      print('3. buscar livro por titulo')
      print('4. gerar grafico por genero')
      print('5. sair')
      opcao = input('Escolha uma opção: ')

      if opcao == '1':
          cadastrar_livro()
      elif opcao == '2':
          listar_livros()
      elif opcao == '3':
          buscar_livro()
      elif opcao == '4':
          gerar_grafico()
      elif opcao == '5':
          print('saindo do sistema.')
          break
      else:
        print('opção invalida. tente novamente.')

# iniciar o sistema
if __name__ == '__main__':
    menu()
# Out:
# --- Biblioteca ---
# 1. cadastrar livro
# 2. listar livros
# 3. buscar livro por titulo
# 4. gerar grafico por genero
# 5. sair
# Escolha uma opção: 1
# titulo:harry potter
# autor:ksksk
# ano:1990
# genero:acao
# livro cadastrado com sucesso!
#
# --- Biblioteca ---
# 1. cadastrar livro
# 2. listar livros
# 3. buscar livro por titulo
# 4. gerar grafico por genero
# 5. sair
# Escolha uma opção: 3
# digite o titulo do livro:harry potter
# livros encontrados:
# harry potter - ksksk (1990) | genero: acao
#
# --- Biblioteca ---
# 1. cadastrar livro
# 2. listar livros
# 3. buscar livro por titulo
# 4. gerar grafico por genero
# 5. sair
# Escolha uma opção: 4
# --- Biblioteca ---
# 1. cadastrar livro
# 2. listar livros
# 3. buscar livro por titulo
# 4. gerar grafico por genero
# 5. sair
